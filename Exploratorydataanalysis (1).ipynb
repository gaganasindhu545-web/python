# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


data = {
    "Name": ["Alice", "Bob", "Charlie", "David", None],
    "Age": [23, 25, np.nan, 30, 28],
    "Gender": ["F", "M", "M", None, "F"],
    "Salary": [50000, 55000, 60000, 65000, None]
}

df = pd.DataFrame(data)
print(df)
print(df.isnull().sum())
df["Name"] = df["Name"].fillna("Unknown")
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Gender"] = df["Gender"].fillna("Not Specified")
df["Salary"] = df["Salary"].fillna(df["Salary"].median())
print(df)

plt.hist(df["Age"])
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution")
plt.show()

salary_by_gender = df.groupby("Gender")["Salary"].mean()

plt.bar(salary_by_gender.index, salary_by_gender.values)
plt.xlabel("Gender")
plt.ylabel("Average Salary")
plt.title("Average Salary by Gender")
plt.show()

plt.scatter(df["Age"], df["Salary"])
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary Scatter Plot")
plt.show()
# Out:
#       Name   Age Gender   Salary
# 0    Alice  23.0      F  50000.0
# 1      Bob  25.0      M  55000.0
# 2  Charlie   NaN      M  60000.0
# 3    David  30.0   None  65000.0
# 4     None  28.0      F      NaN
# Name      1
# Age       1
# Gender    1
# Salary    1
# dtype: int64
#       Name   Age         Gender   Salary
# 0    Alice  23.0              F  50000.0
# 1      Bob  25.0              M  55000.0
# 2  Charlie  26.5              M  60000.0
# 3    David  30.0  Not Specified  65000.0
# 4  Unknown  28.0              F  57500.0
